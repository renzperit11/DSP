# %% [markdown]
# <a href="https://colab.research.google.com/github/renzperit11/DSP/blob/main/audio_recognition_project/renz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from thinkdsp import read_wave

myVoice = read_wave('thevoiceECE.wav')
spec = myVoice.make_spectrum()

spec.plot()
